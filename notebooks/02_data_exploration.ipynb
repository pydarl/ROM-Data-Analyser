# %%
import numpy as np
from numpy import pi
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 2* pi, 100)

# %%
f = np.sin(x)

# %%
plt.plot(f)

# %%
a = np.ones((2,6))

# %%
b = np.empty((2,6), dtype=int)
print(b)
# Out:
# [[  591751050  1071898369 -2080673046  1070961932   591751050  1071898369]
#  [   26724241  1074799109  1641631944  1075204842 -2080673046  1070961932]]
