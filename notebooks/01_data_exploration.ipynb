# %%
import os
os.chdir(r"C:\Users\darli\Documents\GitHub\ROM-Data-Analyser")
print(os.getcwd())
# Out:
# C:\Users\darli\Documents\GitHub\ROM-Data-Analyser

# %%
import pandas as pd

df = pd.read_csv("data/raw/injury_dataset.csv")
df.head()
# Out:
#    Player_ID  Age  Height_cm  Weight_kg Position           Injury_Type  \
# 0          1   24        195        108   Center              ACL Tear
# 1          2   32        183         87  Forward          Ankle Sprain
# 2          3   28        208        109   Center           Knee Injury
# 3          4   25        196         70  Forward  Shoulder Dislocation
# 4          5   24        178         80    Guard  Shoulder Dislocation
#
#   Injury_Severity Rehabilitation_Program  Rehabilitation_Time_weeks  \
# 0          Severe          Physiotherapy                          7
# 1            Mild          Physiotherapy                          8
# 2        Moderate  Flexibility Exercises                          3
# 3        Moderate      Strength Training                         11
# 4        Moderate       Balance Training                          3
#
#    Injury_Recurrence Date_of_Injury  Rehabilitation_Efficiency_Score  \
# ...

# %%
df.tail()
# Out:
#     Player_ID  Age  Height_cm  Weight_kg Position           Injury_Type  \
# 95         96   32        189        100   Center           Knee Injury
# 96         97   31        201         72  Forward          Ankle Sprain
# 97         98   20        176        109    Guard          Ankle Sprain
# 98         99   18        202         93   Center  Shoulder Dislocation
# 99        100   22        209        101  Forward          Ankle Sprain
#
#    Injury_Severity Rehabilitation_Program  Rehabilitation_Time_weeks  \
# 95            Mild          Physiotherapy                          6
# 96        Moderate  Flexibility Exercises                         11
# 97          Severe      Strength Training                         11
# 98            Mild       Balance Training                          6
# 99          Severe       Balance Training                          8
#
#     Injury_Recurrence Date_of_Injury  Rehabilitation_Efficiency_Score  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 17 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Player_ID                        100 non-null    int64
#  1   Age                              100 non-null    int64
#  2   Height_cm                        100 non-null    int64
#  3   Weight_kg                        100 non-null    int64
#  4   Position                         100 non-null    object
#  5   Injury_Type                      100 non-null    object
#  6   Injury_Severity                  100 non-null    object
#  7   Rehabilitation_Program           100 non-null    object
#  8   Rehabilitation_Time_weeks        100 non-null    int64
#  9   Injury_Recurrence                100 non-null    int64
#  10  Date_of_Injury                   100 non-null    object
#  11  Rehabilitation_Efficiency_Score  100 non-null    float64
# ...

# %%
df.loc[:, ["Player_ID", "speed_m_s"]]
# Out:
#     Player_ID  speed_m_s
# 0           1  56.578469
# 1           2  71.320646
# 2           3  48.764455
# 3           4  73.690424
# 4           5  58.658816
# ..        ...        ...
# 95         96  86.459280
# 96         97  76.114836
# 97         98  78.459360
# 98         99  89.443696
# 99        100  47.476761
#
# [100 rows x 2 columns]

# %%
df.iloc[0:3]
# Out:
#    Player_ID  Age  Height_cm  Weight_kg Position   Injury_Type  \
# 0          1   24        195        108   Center      ACL Tear
# 1          2   32        183         87  Forward  Ankle Sprain
# 2          3   28        208        109   Center   Knee Injury
#
#   Injury_Severity Rehabilitation_Program  Rehabilitation_Time_weeks  \
# 0          Severe          Physiotherapy                          7
# 1            Mild          Physiotherapy                          8
# 2        Moderate  Flexibility Exercises                          3
#
#    Injury_Recurrence Date_of_Injury  Rehabilitation_Efficiency_Score  \
# 0                  0     2017-12-19                         0.862860
# 1                  0     2017-08-10                         0.806708
# 2                  0     2018-11-21                         0.709122
#
#    knee_angle_deg  jump_height_cm  ankle_flexion_deg  speed_m_s  \
# 0       78.327638       77.705191          37.926663  56.578469
# ...

# %%
df.loc[:, ["Age", "Rehabilitation_Time_weeks"]]
# Out:
#     Age  Rehabilitation_Time_weeks
# 0    24                          7
# 1    32                          8
# 2    28                          3
# 3    25                         11
# 4    24                          3
# ..  ...                        ...
# 95   32                          6
# 96   31                         11
# 97   20                         11
# 98   18                          6
# 99   22                          8
#
# [100 rows x 2 columns]

# %%
df.loc[df.Injury_Recurrence >= 1]
# Out:
#     Player_ID  Age  Height_cm  Weight_kg Position           Injury_Type  \
# 4           5   24        178         80    Guard  Shoulder Dislocation
# 5           6   28        184         97    Guard          Ankle Sprain
# 8           9   25        182        100   Center          Ankle Sprain
# 13         14   19        199         95  Forward              ACL Tear
# 14         15   18        206         71    Guard          Ankle Sprain
# 15         16   29        192         70   Center           Knee Injury
# 17         18   34        184         74    Guard              ACL Tear
# 21         22   32        201        104    Guard  Shoulder Dislocation
# 22         23   29        176         88    Guard           Knee Injury
# 24         25   22        197         72   Center  Shoulder Dislocation
# 41         42   25        175         87  Forward           Knee Injury
# 44         45   23        178         85    Guard      Hamstring Strain
# ...

# %%
df.isnull()
# Out:
#     Player_ID    Age  Height_cm  Weight_kg  Position  Injury_Type  \
# 0       False  False      False      False     False        False
# 1       False  False      False      False     False        False
# 2       False  False      False      False     False        False
# 3       False  False      False      False     False        False
# 4       False  False      False      False     False        False
# ..        ...    ...        ...        ...       ...          ...
# 95      False  False      False      False     False        False
# 96      False  False      False      False     False        False
# 97      False  False      False      False     False        False
# 98      False  False      False      False     False        False
# 99      False  False      False      False     False        False
#
#     Injury_Severity  Rehabilitation_Program  Rehabilitation_Time_weeks  \
# 0             False                   False                      False
# ...

# %%
df.isna()
# Out:
#     Player_ID    Age  Height_cm  Weight_kg  Position  Injury_Type  \
# 0       False  False      False      False     False        False
# 1       False  False      False      False     False        False
# 2       False  False      False      False     False        False
# 3       False  False      False      False     False        False
# 4       False  False      False      False     False        False
# ..        ...    ...        ...        ...       ...          ...
# 95      False  False      False      False     False        False
# 96      False  False      False      False     False        False
# 97      False  False      False      False     False        False
# 98      False  False      False      False     False        False
# 99      False  False      False      False     False        False
#
#     Injury_Severity  Rehabilitation_Program  Rehabilitation_Time_weeks  \
# 0             False                   False                      False
# ...

# %%
df.isna().sum()
# Out:
# Player_ID                          0
# Age                                0
# Height_cm                          0
# Weight_kg                          0
# Position                           0
# Injury_Type                        0
# Injury_Severity                    0
# Rehabilitation_Program             0
# Rehabilitation_Time_weeks          0
# Injury_Recurrence                  0
# Date_of_Injury                     0
# Rehabilitation_Efficiency_Score    0
# knee_angle_deg                     0
# jump_height_cm                     0
# ankle_flexion_deg                  0
# speed_m_s                          0
# reaction_time_ms                   0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.isna().any()
# Out:
# Player_ID                          False
# Age                                False
# Height_cm                          False
# Weight_kg                          False
# Position                           False
# Injury_Type                        False
# Injury_Severity                    False
# Rehabilitation_Program             False
# Rehabilitation_Time_weeks          False
# Injury_Recurrence                  False
# Date_of_Injury                     False
# Rehabilitation_Efficiency_Score    False
# knee_angle_deg                     False
# jump_height_cm                     False
# ankle_flexion_deg                  False
# speed_m_s                          False
# reaction_time_ms                   False
# dtype: bool

# %%
df.describe()
# Out:
#         Player_ID         Age   Height_cm   Weight_kg  \
# count  100.000000  100.000000  100.000000  100.000000
# mean    50.500000   25.480000  190.060000   92.070000
# std     29.011492    4.835642   12.126288   11.446189
# min      1.000000   18.000000  170.000000   70.000000
# 25%     25.750000   21.000000  179.500000   85.000000
# 50%     50.500000   25.000000  192.000000   94.000000
# 75%     75.250000   29.000000  201.000000  102.000000
# max    100.000000   34.000000  209.000000  109.000000
#
#        Rehabilitation_Time_weeks  Injury_Recurrence  \
# count                  100.00000         100.000000
# mean                     6.92000           0.250000
# std                      2.95652           0.435194
# min                      2.00000           0.000000
# 25%                      4.75000           0.000000
# 50%                      7.00000           0.000000
# 75%                      9.25000           0.250000
# max                     11.00000           1.000000
#
# ...

# %%
df.loc[df.Age.isna()]
# Out:
# Empty DataFrame
# Columns: [Player_ID, Age, Height_cm, Weight_kg, Position, Injury_Type, Injury_Severity, Rehabilitation_Program, Rehabilitation_Time_weeks, Injury_Recurrence, Date_of_Injury, Rehabilitation_Efficiency_Score, knee_angle_deg, jump_height_cm, ankle_flexion_deg, speed_m_s, reaction_time_ms]
# Index: []

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Length: 100, dtype: bool

# %%
df.columns.duplicated()
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False])

# %%
df.dtypes
# Out:
# Player_ID                            int64
# Age                                  int64
# Height_cm                            int64
# Weight_kg                            int64
# Position                            object
# Injury_Type                         object
# Injury_Severity                     object
# Rehabilitation_Program              object
# Rehabilitation_Time_weeks            int64
# Injury_Recurrence                    int64
# Date_of_Injury                      object
# Rehabilitation_Efficiency_Score    float64
# knee_angle_deg                     float64
# jump_height_cm                     float64
# ankle_flexion_deg                  float64
# speed_m_s                          float64
# reaction_time_ms                   float64
# dtype: object

# %%
df.loc[df.knee_angle_deg < 35]
# Out:
#     Player_ID  Age  Height_cm  Weight_kg Position   Injury_Type  \
# 1           2   32        183         87  Forward  Ankle Sprain
# 7           8   21        195         92  Forward  Ankle Sprain
# 19         20   33        205        101  Forward  Ankle Sprain
# 31         32   19        180        105    Guard  Ankle Sprain
# 92         93   18        195         72  Forward      ACL Tear
# 95         96   32        189        100   Center   Knee Injury
#
#    Injury_Severity Rehabilitation_Program  Rehabilitation_Time_weeks  \
# 1             Mild          Physiotherapy                          8
# 7             Mild          Physiotherapy                          9
# 19        Moderate       Balance Training                         11
# 31          Severe      Strength Training                          7
# 92          Severe       Balance Training                          6
# 95            Mild          Physiotherapy                          6
#
# ...
